# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
t1 = pd.read_csv('Mortality/T1.csv', )
t1.columns = t1.iloc[0]
t1 = t1[1:]
t1.reset_index(drop=True, inplace=True)

# %%
t1.columns = t1.columns.astype(str)
t1.columns = [col.strip('0') for col in t1.columns]
t1.columns = [col.strip('.') for col in t1.columns]
t1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
t1.head()
# Out:
#            Country Name Country Code  \
# 0  United Arab Emirates          ARE
# 1   Antigua and Barbuda          ATG
# 2             Australia          AUS
# 3               Austria          AUT
# 4               Belgium          BEL
#
#                                    Indicator Name  Indicator Code   1960  \
# 0  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN  135.5
# 1  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   62.9
# 2  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   20.3
# 3  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   37.3
# 4  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   29.4
#
#     1961   1962   1963   1964   1965  ...  2012  2013  2014  2015  2016  2017  \
# 0  128.9  122.5  116.2  109.9  103.3  ...   7.0   6.8   6.7   6.5   6.3   6.2
# 1   58.8   54.3   49.6   44.9   40.4  ...   7.5   7.1   6.8   6.5   6.2   6.0
# ...

# %%
t1.shape
# Out:
# (117, 66)

# %%
t1.drop(['Indicator Code', 'Country Code'], axis=1, inplace=True)

# %%
australia = t1.loc[t1['Country Name']=='Australia']
australia
# Out:
#   Country Name                                  Indicator Name  1960  1961  \
# 2    Australia  Mortality rate, infant (per 1,000 live births)  20.3  19.9
#
#    1962  1963  1964  1965  1966  1967  ...  2012  2013  2014  2015  2016  \
# 2  19.5  19.1  18.7  18.5  18.3  18.2  ...   3.6   3.5   3.3   3.3   3.2
#
#    2017  2018  2019  2020  2021
# 2   3.2   3.2   3.2   3.2   3.2
#
# [1 rows x 64 columns]

# %%
australia = australia.transpose()
australia.columns = australia.iloc[0]
australia = australia[2:]

# %%
australia
# Out:
# Country Name Australia
# 1960              20.3
# 1961              19.9
# 1962              19.5
# 1963              19.1
# 1964              18.7
# ...                ...
# 2017               3.2
# 2018               3.2
# 2019               3.2
# 2020               3.2
# 2021               3.2
#
# [62 rows x 1 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(australia['Australia'])
plt.xticks(rotation=90)

plt.show()

# %%
t1.drop('Indicator Name', axis=1, inplace=True)

# %%
t1.head()
# Out:
#            Country Name   1960   1961   1962   1963   1964   1965  1966  1967  \
# 0  United Arab Emirates  135.5  128.9  122.5  116.2  109.9  103.3  96.6  89.8
# 1   Antigua and Barbuda   62.9   58.8   54.3   49.6   44.9   40.4  36.1  32.3
# 2             Australia   20.3   19.9   19.5   19.1   18.7   18.5  18.3  18.2
# 3               Austria   37.3   34.9   32.9   31.1   29.6   28.3  27.2  26.3
# 4               Belgium   29.4   28.1   27.0   26.0   25.0   24.0  23.2  22.5
#
#    1968  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  83.1  ...   7.0   6.8   6.7   6.5   6.3   6.2   6.0   5.8   5.6   5.4
# 1  29.0  ...   7.5   7.1   6.8   6.5   6.2   6.0   5.7   5.5   5.3   5.2
# 2  18.1  ...   3.6   3.5   3.3   3.3   3.2   3.2   3.2   3.2   3.2   3.2
# 3  25.7  ...   3.3   3.2   3.1   3.0   3.0   2.9   2.9   2.9   3.0   3.0
# 4  21.9  ...   3.5   3.4   3.4   3.4   3.3   3.4   3.4   3.4   3.4   3.4
#
# [5 rows x 63 columns]

# %%
max_val_2021 = t1['2021'].idxmax()
t1.loc[max_val_2021]
# Out:
# Country Name    Sierra Leone
# 1960                   220.4
# 1961                   217.3
# 1962                   214.3
# 1963                   211.1
#                     ...
# 2017                    87.6
# 2018                    85.2
# 2019                    82.8
# 2020                    80.5
# 2021                    78.3
# Name: 94, Length: 63, dtype: object

# %%
min_idx_1960 = t1['1960'].idxmin()
t1.loc[min_idx_1960]
# Out:
# Country Name    Sweden
# 1960              16.3
# 1961              16.0
# 1962              15.6
# 1963              15.0
#                  ...
# 2017               2.3
# 2018               2.2
# 2019               2.1
# 2020               2.1
# 2021               2.0
# Name: 96, Length: 63, dtype: object

# %%
min_idx_2021 = t1['2021'].idxmin()
t1.loc[min_idx_2021]
# Out:
# Country Name    Japan
# 1960             30.4
# 1961             27.9
# 1962             25.5
# 1963             23.1
#                 ...
# 2017              1.9
# 2018              1.9
# 2019              1.8
# 2020              1.8
# 2021              1.7
# Name: 56, Length: 63, dtype: object

# %%
japan = t1.loc[t1['Country Name'] == 'Japan']
japan
# Out:
#    Country Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...  \
# 56        Japan  30.4  27.9  25.5  23.1  21.0  19.1  17.6  16.3  15.1  ...
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 56   2.2   2.1   2.1   2.0   2.0   1.9   1.9   1.8   1.8   1.7
#
# [1 rows x 63 columns]

# %%
japan = japan.transpose()
japan.columns = japan.iloc[0]
japan = japan[1:]
japan
# Out:
# Country Name Japan
# 1960          30.4
# 1961          27.9
# 1962          25.5
# 1963          23.1
# 1964          21.0
# ...            ...
# 2017           1.9
# 2018           1.9
# 2019           1.8
# 2020           1.8
# 2021           1.7
#
# [62 rows x 1 columns]

# %%
plt.figure(figsize=(16, 9))
sns.lineplot(japan['Japan'])
plt.xticks(rotation=90)
plt.show()

# %%
t1.loc[t1['2021'] > 10.].count()
# Out:
# Country Name    70
# 1960            70
# 1961            70
# 1962            70
# 1963            70
#                 ..
# 2017            70
# 2018            70
# 2019            70
# 2020            70
# 2021            70
# Length: 63, dtype: int64
